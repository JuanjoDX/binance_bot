# %%
tickers = client.futures_ticker() ### tickers es decir monedas en futuros
ticker_df = pd.DataFrame(tickers)
ticker_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12364/4251182314.py in <module>
# ----> 1 tickers = client.futures_ticker() ### tickers es decir monedas en futuros
#       2 ticker_df = pd.DataFrame(tickers)
#       3 ticker_df
#
# NameError: name 'client' is not defined

# %%
apikey = 'o4xp0nX8Nr3RsQIAQDBs7ZZivwpoLHPZsDQU48dmWX8heBKpSgPOS0M9NZwHHbEP'
secret = 'OwjJSwLt0szX7qq62Xqd7evsc345eCLCTrYIVTdIND4HORYJ4DDz7lmGnDGCMiwq'

# %%
from binance import Client, ThreadedWebsocketManager, ThreadedDepthCacheManager
import pandas as pd
from datetime import datetime, timedelta
now = datetime.now()

now
# Out:
# datetime.datetime(2023, 8, 16, 18, 14, 21, 348982)

# %%
client = Client(apikey, secret)
client.futures_get_open_orders()
# Out:
# []

# %%
res = client.futures_position_information()
target_symbol = '1000SHIBUSDT'

# Buscar el diccionario con el símbolo deseado
target_position = None
for position in res:
    if position['symbol'] == target_symbol:
        target_position = position
        break

print(target_position)
# Out:
# {'symbol': '1000SHIBUSDT', 'positionAmt': '0', 'entryPrice': '0.0', 'markPrice': '0.00930900', 'unRealizedProfit': '0.00000000', 'liquidationPrice': '0', 'leverage': '20', 'maxNotionalValue': '600000', 'marginType': 'cross', 'isolatedMargin': '0.00000000', 'isAutoAddMargin': 'false', 'positionSide': 'BOTH', 'notional': '0', 'isolatedWallet': '0', 'updateTime': 1692126466388}

# %%
client.futures_create_order(symbol = '1000SHIBUSDT',
                            side = 'SELL',
                            price = '0.010480',
                            quantity = '128240',
                            type = 'LIMIT',
                            timeinforce = 'GTC',
                            reduceOnly = True)
# Out:
# ---------------------------------------------------------------------------
# BinanceAPIException                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12364/3237129275.py in <module>
# ----> 1 client.futures_create_order(symbol = '1000SHIBUSDT',
#       2                             side = 'SELL',
#       3                             price = '0.010480',
#       4                             quantity = '128240',
#       5                             type = 'LIMIT',
#
# ~\anaconda3\lib\site-packages\binance\client.py in futures_create_order(self, **params)
#    6207
#    6208         """
# -> 6209         return self._request_futures_api('post', 'order', True, data=params)
#    6210
#    6211     def futures_place_batch_order(self, **params):
#
# ~\anaconda3\lib\site-packages\binance\client.py in _request_futures_api(self, method, path, signed, **kwargs)
#     380         uri = self._create_futures_api_uri(path)
#     381
# ...

# %%
client = Client(apikey, secret)
res = client.get_exchange_info() ### de aca deberia sacar la ultima hora 
hora_ser = pd.to_datetime(res["serverTime"]/1000, unit='s')

hora_inicio = hora_ser-timedelta(days = 200)

# %%
historical = client.futures_historical_klines(symbol='1000SHIBUSDT',
    interval='1m',
    start_str=hora_inicio.date(),
    end_str=str(hora_ser)
)

hist_df = pd.DataFrame(historical)
hist_df.columns = ['Open Time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Close Time', 'Quote Asset Volume', 
                    'Number of Trades', 'TB Base Volume', 'TB Quote Volume', 'Ignore']

hist_df['Open Time'] = pd.to_datetime(hist_df['Open Time']/1000, unit='s')
hist_df['Close Time'] = pd.to_datetime(hist_df['Close Time']/1000, unit='s')

numeric_columns = ['Open', 'High', 'Low', 'Close', 'Volume', 'Quote Asset Volume', 'TB Base Volume', 'TB Quote Volume']
hist_df[numeric_columns] = hist_df[numeric_columns].apply(pd.to_numeric, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12364/1990674149.py in <module>
# ----> 1 historical = client.futures_historical_klines(symbol='1000SHIBUSDT',
#       2     interval='1m',
#       3     start_str=hora_inicio.date(),
#       4     end_str=str(hora_ser)
#       5 )
#
# ~\anaconda3\lib\site-packages\binance\client.py in futures_historical_klines(self, symbol, interval, start_str, end_str, limit)
#    6038
#    6039         """
# -> 6040         return self._historical_klines(symbol, interval, start_str, end_str=end_str, limit=limit, klines_type=HistoricalKlinesType.FUTURES)
#    6041
#    6042     def futures_historical_klines_generator(self, symbol, interval, start_str, end_str=None):
#
# ~\anaconda3\lib\site-packages\binance\client.py in _historical_klines(self, symbol, interval, start_str, end_str, limit, klines_type)
#    1017
# ...

# %%
hist_df.to_excel("././data_prueba.xlsx",index = False)

# %%
import mplfinance as mpf
mpf.plot(hist_df.set_index('Close Time').tail(120), 
        type='candle', style='charles', 
        volume=True, 
        title='SHIBUSDT Last 120 MINS', 
        mav=(9,25,99))

# %%
def hist(coin, mins):    
    client = Client(apikey, secret)
    res = client.get_exchange_info() ### de aca deberia sacar la ultima hora 
    hora_ser = pd.to_datetime(res["serverTime"]/1000, unit='s')
    hora_inicio = hora_ser-timedelta(days = 5)
    
    historical = client.futures_historical_klines(symbol=coin,
                                                  interval='1m',
                                                  start_str=str(hora_inicio),
                                                  end_str=str(hora_ser)
                                                 )                                                

    hist_df = pd.DataFrame(historical)
    hist_df.columns = ['Open Time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Close Time', 'Quote Asset Volume', 
                        'Number of Trades', 'TB Base Volume', 'TB Quote Volume', 'Ignore']

    hist_df['Open Time'] = pd.to_datetime(hist_df['Open Time']/1000, unit='s')
    hist_df['Close Time'] = pd.to_datetime(hist_df['Close Time']/1000, unit='s')

    numeric_columns = ['Open', 'High', 'Low', 'Close', 'Volume', 'Quote Asset Volume', 'TB Base Volume', 'TB Quote Volume']
    hist_df[numeric_columns] = hist_df[numeric_columns].apply(pd.to_numeric, axis=1)
    
    mpf.plot(hist_df.set_index('Close Time').tail(mins), 
        type='candle', style='charles', 
        volume=True, 
        title='SHIBUSDT Last {0} MINS'.format(mins), 
        mav=(9,25,99))

# %%
hist("1000SHIBUSDT",60)
